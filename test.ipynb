# %%
from streamlit_utils import *
os.environ["CUDA_VISIBLE_DEVICES"] = ""

data_path = '/workspaces/vessel/streamlit/data'
mag_series_uid = '1.3.6.1.4.1.53684.1.1.3.1887816670.2028.1636387520.819538'
phase_series_uid = '1.3.6.1.4.1.53684.1.1.3.1887816670.2028.1636387520.819538'
# Out:
# 2025-11-07 17:44:15.843203: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-07 17:44:16.040703: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-07 17:44:16.040755: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-07 17:44:16.061332: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
image, venc, rr, description, patient, study_date =  get_image(data_path, mag_series_uid, phase_series_uid)
# Out:
# magnitude-weighted
# 2025-11-07 17:44:19.649696: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:274] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-11-07 17:44:19.649717: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:129] retrieving CUDA diagnostic information for host: 16b9af42f91b
# 2025-11-07 17:44:19.649721: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:136] hostname: 16b9af42f91b
# 2025-11-07 17:44:19.649779: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:159] libcuda reported version is: 560.35.3
# 2025-11-07 17:44:19.649792: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:163] kernel reported version is: NOT_FOUND: could not find kernel module information in driver version file contents: "NVRM version: NVIDIA UNIX Open Kernel Module for x86_64  560.35.03  Release Build  (dvs-builder@U16-I1-N07-12-3)  Fri Aug 16 21:42:42 UTC 2024
# ...
